# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 1

# %%
df = pd.read_csv("C:\\Users\\anand\\Desktop\\SOC 2.0\\data.csv")
df
# Out:
#        loanNumber originationDate  loanAmount   loanTerm  intRate  \
# 0         5274786         06/2022    30834.27  73 months   0.0319
# 1         6224415         08/2017    35694.04      6 yrs   0.0190
# 2         5254898         07/2022    37729.22  62 months   0.0479
# 3         5267640         06/2022    39990.00        76m   0.0399
# 4         5385389         11/2021    33157.92  64 months   0.0199
# ...           ...             ...         ...        ...      ...
# 50038     6092858         04/2018    38662.94  61 months   0.0190
# 50039     6100955         03/2018    21000.00  62 months   0.0090
# 50040     5244136         08/2022    35417.32        61m   0.0624
# 50041     6118657         02/2018    26315.52  78 months   0.0569
# 50042     5281029         05/2022    47025.38         6y   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# ...

# %%
 df['loanTerm'] = df['loanTerm'].str.replace('\D', '', regex=True)
df
# removing all the str values in the loanTerm column
# Out:
#        loanNumber originationDate  loanAmount loanTerm  intRate  \
# 0         5274786         06/2022    30834.27       73   0.0319
# 1         6224415         08/2017    35694.04        6   0.0190
# 2         5254898         07/2022    37729.22       62   0.0479
# 3         5267640         06/2022    39990.00       76   0.0399
# 4         5385389         11/2021    33157.92       64   0.0199
# ...           ...             ...         ...      ...      ...
# 50038     6092858         04/2018    38662.94       61   0.0190
# 50039     6100955         03/2018    21000.00       62   0.0090
# 50040     5244136         08/2022    35417.32       61   0.0624
# 50041     6118657         02/2018    26315.52       78   0.0569
# 50042     5281029         05/2022    47025.38        6   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df['loanTerm']= df['loanTerm'].astype(float)
df
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786         06/2022    30834.27      73.0   0.0319
# 1         6224415         08/2017    35694.04       6.0   0.0190
# 2         5254898         07/2022    37729.22      62.0   0.0479
# 3         5267640         06/2022    39990.00      76.0   0.0399
# 4         5385389         11/2021    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858         04/2018    38662.94      61.0   0.0190
# 50039     6100955         03/2018    21000.00      62.0   0.0090
# 50040     5244136         08/2022    35417.32      61.0   0.0624
# 50041     6118657         02/2018    26315.52      78.0   0.0569
# 50042     5281029         05/2022    47025.38       6.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df.loc[df['loanTerm'] <= 9, 'loanTerm'] *= 12
df
#I noticed in the data that loanTerm whose value was shown in years was less than or equal to 9 therefore I applied the above condition
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786         06/2022    30834.27      73.0   0.0319
# 1         6224415         08/2017    35694.04      72.0   0.0190
# 2         5254898         07/2022    37729.22      62.0   0.0479
# 3         5267640         06/2022    39990.00      76.0   0.0399
# 4         5385389         11/2021    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858         04/2018    38662.94      61.0   0.0190
# 50039     6100955         03/2018    21000.00      62.0   0.0090
# 50040     5244136         08/2022    35417.32      61.0   0.0624
# 50041     6118657         02/2018    26315.52      78.0   0.0569
# 50042     5281029         05/2022    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df15 = df.copy()
df15['originationDate'] = pd.to_datetime(df15['originationDate'])
df15
#converting OriginationDate coulumn into datetime format
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 2         5254898      2022-07-01    37729.22      62.0   0.0479
# 3         5267640      2022-06-01    39990.00      76.0   0.0399
# 4         5385389      2021-11-01    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
# 50039     6100955      2018-03-01    21000.00      62.0   0.0090
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
# 50041     6118657      2018-02-01    26315.52      78.0   0.0569
# 50042     5281029      2022-05-01    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
from datetime import datetime as dt
df15['originationDate'] = df15['originationDate'].dt.strftime('%m/%d/%Y')
df15
# changing the format of date into dd/mm/yyyy from yyyy/mm/dd
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      06/01/2022    30834.27      73.0   0.0319
# 1         6224415      08/01/2017    35694.04      72.0   0.0190
# 2         5254898      07/01/2022    37729.22      62.0   0.0479
# 3         5267640      06/01/2022    39990.00      76.0   0.0399
# 4         5385389      11/01/2021    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      04/01/2018    38662.94      61.0   0.0190
# 50039     6100955      03/01/2018    21000.00      62.0   0.0090
# 50040     5244136      08/01/2022    35417.32      61.0   0.0624
# 50041     6118657      02/01/2018    26315.52      78.0   0.0569
# 50042     5281029      05/01/2022    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df15['loanTerm'] = df15['loanTerm'].fillna(0)
df15.replace([np.inf, -np.inf], np.nan, inplace=True)
df15['loanTerm'] = df15['loanTerm'].astype(int)
df15
#filling 0 instead of na and inf values in the column loanTerm
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      06/01/2022    30834.27        73   0.0319
# 1         6224415      08/01/2017    35694.04        72   0.0190
# 2         5254898      07/01/2022    37729.22        62   0.0479
# 3         5267640      06/01/2022    39990.00        76   0.0399
# 4         5385389      11/01/2021    33157.92        64   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      04/01/2018    38662.94        61   0.0190
# 50039     6100955      03/01/2018    21000.00        62   0.0090
# 50040     5244136      08/01/2022    35417.32        61   0.0624
# 50041     6118657      02/01/2018    26315.52        78   0.0569
# 50042     5281029      05/01/2022    47025.38        72   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df15['loanTerm'].dtype
# Out:
# dtype('int32')

# %%
df15['maturity_date'] = df15['originationDate'] + pd.DateOffset(months = df15['loanTerm'])
df15['maturity_date']
# there seems to be some ambiguity over here, as far as I know the code is correct but it doesn't seem to be working here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [498], in <cell line: 1>()
# ----> 1 df15['maturity_date'] = df15['originationDate'] + pd.DateOffset(months = df15['loanTerm'])
#       2 df15
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:1029, in pandas._libs.tslibs.offsets.RelativeDeltaOffset.__init__()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:331, in pandas._libs.tslibs.offsets._determine_offset()
#
# File ~\anaconda3\lib\site-packages\dateutil\relativedelta.py:172, in relativedelta.__init__(self, dt1, dt2, years, months, days, leapdays, weeks, hours, minutes, seconds, microseconds, year, month, day, weekday, yearday, nlyearday, hour, minute, second, microsecond)
#     169     self.microseconds = delta.microseconds
#     170 else:
#     171     # Check for non-integer values in integer-only quantities
# ...

# %% [markdown]
# # Question 2

# %%
#cannot calculate as I was unable to calculate maturity date

# %% [markdown]
# # Question 3

# %%
df['obligorState']
# Out:
# 0        FL
# 1        FL
# 2        NC
# 3        SC
# 4        NC
#          ..
# 50038    NC
# 50039    NC
# 50040    FL
# 50041    NC
# 50042    AR
# Name: obligorState, Length: 50043, dtype: object

# %%
# Total number of loans = 50043

# %%
Loan_Count = df.groupby(['obligorState']).count()
Loan_Count
# Out:
#               loanNumber  originationDate  loanAmount  loanTerm  intRate  \
# obligorState
# AK                     8                8           8         8        8
# AL                  5560             5560        5560      5560     5560
# AR                    18               18          18        18       18
# AZ                    43               43          43        43       43
# CA                   128              128         128       128      128
# CO                    51               51          51        51       51
# CT                    35               35          35        35       35
# DC                    11               11          11        11       11
# DE                    12               12          12        12       12
# FL                 17328            17328       17328     17328    17328
# GA                 10968            10968       10968     10965    10968
# HI                     7                7           7         7        7
# ...

# %%
Sum1 = Loan_Count['loanNumber'].sum()
Sum1 #The total number of loans
# Out:
# 50043

# %%
Loan_Count['percentageofloans'] = 100 * Loan_Count['loanNumber'] / Sum1
Loan_Count #Adding a coulumn which represent the percenatge of loans by Loan Count
# Out:
#               loanNumber  originationDate  loanAmount  loanTerm  intRate  \
# obligorState
# AK                     8                8           8         8        8
# AL                  5560             5560        5560      5560     5560
# AR                    18               18          18        18       18
# AZ                    43               43          43        43       43
# CA                   128              128         128       128      128
# CO                    51               51          51        51       51
# CT                    35               35          35        35       35
# DC                    11               11          11        11       11
# DE                    12               12          12        12       12
# FL                 17328            17328       17328     17328    17328
# GA                 10968            10968       10968     10965    10968
# HI                     7                7           7         7        7
# ...

# %%
Loan_Count['percentageofloans'].nlargest(2)
# Out:
# obligorState
# FL    34.626221
# GA    21.917151
# Name: percentageofloans, dtype: float64

# %%
# Answer- obligorState 'GA' has the highest percentage of Loans by Loan Count

# %%
State_LoanAmount = df.groupby(['obligorState'])['loanAmount'].sum()
State_LoanAmount #Sum of total Loan Amount in each state
# Out:
# obligorState
# AK    2.768429e+05
# AL    1.812364e+08
# AR    6.203501e+05
# AZ    1.309171e+06
# CA    4.005304e+06
# CO    1.697188e+06
# CT    1.027290e+06
# DC    2.933480e+05
# DE    4.305236e+05
# FL    5.652640e+08
# GA    3.690353e+08
# HI    2.291444e+05
# IA    3.427255e+05
# ID    3.165163e+05
# IL    1.747122e+06
# IN    1.558507e+06
# KS    6.305027e+05
# KY    1.788980e+06
# LA    7.818322e+05
# MA    1.413578e+06
# MD    5.027620e+04
# ME    7.261917e+05
# MI    1.332373e+06
# MN    6.379440e+05
# MO    1.360990e+06
# MS    6.219334e+06
# MT    2.737410e+05
# NC    3.135356e+08
# ND    7.596867e+04
# NE    2.136887e+05
# NH    4.823174e+05
# NJ    2.521832e+06
# NM    2.723684e+05
# NV    6.145807e+05
# NY    4.805614e+06
# OH    2.736404e+06
# OK    6.630904e+05
# OR    3.650997e+05
# PA    7.483239e+04
# RI    5.680484e+04
# SC    1.244389e+08
# SD    1.307325e+05
# TN    1.189636e+07
# TX    5.127965e+05
# UT    3.909479e+05
# VA    9.886173e+06
# ...

# %%
Sum = State_LoanAmount.sum() # sum of total loan amounts of all states
State_LoanAmount['percentage'] = (100 * State_LoanAmount) / Sum
State_LoanAmount['percentage']
# Out:
# obligorState
# AK     0.017071
# AL    11.175646
# AR     0.038253
# AZ     0.080728
# CA     0.246980
# CO     0.104654
# CT     0.063346
# DC     0.018089
# DE     0.026548
# FL    34.856071
# GA    22.755950
# HI     0.014130
# IA     0.021134
# ID     0.019517
# IL     0.107733
# IN     0.096103
# KS     0.038879
# KY     0.110314
# LA     0.048210
# MA     0.087166
# MD     0.003100
# ME     0.044779
# MI     0.082159
# MN     0.039338
# MO     0.083923
# MS     0.383505
# MT     0.016880
# NC    19.333655
# ND     0.004684
# NE     0.013177
# NH     0.029741
# NJ     0.155505
# NM     0.016795
# NV     0.037897
# NY     0.296330
# OH     0.168736
# OK     0.040888
# OR     0.022513
# PA     0.004614
# RI     0.003503
# SC     7.673322
# SD     0.008061
# TN     0.733569
# TX     0.031621
# UT     0.024107
# VA     0.609614
# VT     0.012740
# WA     0.078263
# WI     0.063371
# WV     0.052175
# WY     0.004912
# Name: loanAmount, dtype: float64

# %%
State_LoanAmount['percentage'].nlargest(2)
# Out:
# obligorState
# FL    34.856071
# GA    22.755950
# Name: loanAmount, dtype: float64

# %%
# Obligor State GA has the second highest percentage of loans by Loan Amount

# %% [markdown]
# # Question 4

# %%
df['originationDate'] = pd.to_datetime(df['originationDate'])
df['month'] = df['originationDate'].dt.month
df
#creating a column displaying the month in which loan was generated
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 2         5254898      2022-07-01    37729.22      62.0   0.0479
# 3         5267640      2022-06-01    39990.00      76.0   0.0399
# 4         5385389      2021-11-01    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
# 50039     6100955      2018-03-01    21000.00      62.0   0.0090
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
# 50041     6118657      2018-02-01    26315.52      78.0   0.0569
# 50042     5281029      2022-05-01    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
loans_each_month = df.groupby(['month'])['loanNumber'].count()
loans_each_month
# calculating the number of loans generated in each month
# Out:
# month
# 1     1373
# 2     2805
# 3     3456
# 4     4393
# 5     8991
# 6     7840
# 7     7702
# 8     6467
# 9     1106
# 10    1537
# 11    2743
# 12    1630
# Name: loanNumber, dtype: int64

# %%
sum3 = loans_each_month.sum()
sum3 
#calculating the total number of loans generated
# Out:
# 50043

# %%
percentage_loans_each_month = (100 * loans_each_month) / sum3
percentage_loans_each_month
#calculating the percentage of loans generated in each month
# Out:
# month
# 1      2.743640
# 2      5.605180
# 3      6.906061
# 4      8.778451
# 5     17.966549
# 6     15.666527
# 7     15.390764
# 8     12.922886
# 9      2.210099
# 10     3.071359
# 11     5.481286
# 12     3.257199
# Name: loanNumber, dtype: float64

# %%
# Graph

# %%
percentage_loans_each_month.plot.line(title="percentage of loans each month")
# Out:
# <AxesSubplot:title={'center':'percentage of loans each month'}, xlabel='month'>

# %% [markdown]
# # Question 5

# %%
df['defaultFlag'] = df['beginningLoanBal'] == df['endingLoanBal']
df
# creating a column defaultflag where defaulted loans are shown as 'True' and rest as 'False'
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 2         5254898      2022-07-01    37729.22      62.0   0.0479
# 3         5267640      2022-06-01    39990.00      76.0   0.0399
# 4         5385389      2021-11-01    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
# 50039     6100955      2018-03-01    21000.00      62.0   0.0090
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
# 50041     6118657      2018-02-01    26315.52      78.0   0.0569
# 50042     5281029      2022-05-01    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df['defaultFlag']
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 50038    False
# 50039    False
# 50040    False
# 50041    False
# 50042    False
# Name: defaultFlag, Length: 50043, dtype: bool

# %% [markdown]
# # Question 6

# %%
df5 = df[df['coObligorIndicator'] == 1 ]
df5
# creating a dataframe where the loans have a coObligor
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 5         5247917      2022-07-01    13306.35      62.0   0.0690
# 11        5280807      2022-05-01    37127.50      74.0   0.0499
# 21        5272106      2022-06-01    33437.19      64.0   0.0549
# 23        5253376      2022-07-01    13884.15      62.0   0.0290
# 25        5382680      2021-11-01    33259.77      76.0   0.0694
# ...           ...             ...         ...       ...      ...
# 50028     6316008      2017-02-01    23439.01      76.0   0.0399
# 50029     6333518      2017-01-01    30906.43      77.0   0.0339
# 50036     6112401      2018-03-01    27401.26      74.0   0.0284
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 5              COROLLA               Used              2017
# 11                RAV4                New              2022
# ...

# %%
A = df5['loanNumber'].count()
A
# Out:
# 15187

# %%
#There are 15187 loans which have a coObligor

# %%
df6 = df5[df5['intRate'] <= 0.03]
df6
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 23        5253376      2022-07-01    13884.15      62.0   0.0290
# 30        6118528      2018-02-01    39069.60      75.0   0.0190
# 35        5286005      2022-05-01    32655.22      76.0   0.0299
# 74        6113312      2018-02-01    39039.64      73.0   0.0290
# 75        5257044      2022-07-01    28058.86      37.0   0.0190
# ...           ...             ...         ...       ...      ...
# 49994     5283041      2022-05-01    22804.29      62.0   0.0290
# 50018     5285173      2022-05-01    33992.41      64.0   0.0249
# 50021     5280772      2022-05-01    37642.45      60.0   0.0149
# 50036     6112401      2018-03-01    27401.26      74.0   0.0284
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 23               CAMRY                New              2022
# 30          RAV4 HYBRI                New              2018
# ...

# %%
B = df6['loanNumber'].count()
B
# Out:
# 5236

# %%
#Number of loans which have a coObligor and Interest Rate <= 3%

# %%
C = (100 * B)/ A # B is number of loans having coObligor and paying an interest  rate <= 3%
# A is number of loans having coObligor
print(C)
# C is percentage of loans having a coObligor which pay an Interest rate <= 3%
# Out:
# 34.476855205109636

# %% [markdown]
# # Question 7

# %%
df4 = df[df['obligorState'] == 'FL']
df4
# creating a datframe for obligorState 'Florida'
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 10        6164501      2017-12-01    36810.94      72.0   0.0390
# 18        5278592      2022-05-01    48343.86      74.0   0.0599
# 23        5253376      2022-07-01    13884.15      62.0   0.0290
# ...           ...             ...         ...       ...      ...
# 50019     5276635      2022-05-01    40921.87      77.0   0.0914
# 50028     6316008      2017-02-01    23439.01      76.0   0.0399
# 50030     5242857      2022-08-01    31930.75      72.0   0.0490
# 50031     5275996      2022-06-01    28348.24      76.0   0.0499
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
df4['ModelandYear'] = df4['vehicleModelName'] + df4['vehicleModelYear'].astype(str)
df4['ModelandYear'].astype(str)
df4
#merging the columns 'vehicleModelName' and 'vehicleModelYear'
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_12712\415572146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['ModelandYear'] = df4['vehicleModelName'] + df4['vehicleModelYear'].astype(str)
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 10        6164501      2017-12-01    36810.94      72.0   0.0390
# 18        5278592      2022-05-01    48343.86      74.0   0.0599
# 23        5253376      2022-07-01    13884.15      62.0   0.0290
# ...           ...             ...         ...       ...      ...
# 50019     5276635      2022-05-01    40921.87      77.0   0.0914
# ...

# %%
df4['ModelandYear'].value_counts().idxmax()
# Out:
# 'COROLLA2022'

# %%
df9 = df4[df4['vehicleModelName'] == 'COROLLA']
df10 = df9[df9['vehicleModelYear'] == 2022 ]
df10['loanNumber'].count()
# Out:
# 1819

# %%
# Most popular car model in Florida(FL) state is COROLLA of year 2022(total count of 1819)

# %% [markdown]
# # Question 8

# %%
df['bins'] = pd.qcut(df['obligorCreditScore'], q=5)
df
# Bucketing the column obligorCreditScore into 5 columns and creating a new column bins to show which bucket does each cell belongs to
# Out:
#        loanNumber originationDate  loanAmount  loanTerm  intRate  \
# 0         5274786      2022-06-01    30834.27      73.0   0.0319
# 1         6224415      2017-08-01    35694.04      72.0   0.0190
# 2         5254898      2022-07-01    37729.22      62.0   0.0479
# 3         5267640      2022-06-01    39990.00      76.0   0.0399
# 4         5385389      2021-11-01    33157.92      64.0   0.0199
# ...           ...             ...         ...       ...      ...
# 50038     6092858      2018-04-01    38662.94      61.0   0.0190
# 50039     6100955      2018-03-01    21000.00      62.0   0.0090
# 50040     5244136      2022-08-01    35417.32      61.0   0.0624
# 50041     6118657      2018-02-01    26315.52      78.0   0.0569
# 50042     5281029      2022-05-01    47025.38      72.0   0.0654
#
#       vehicleModelName vehicleNewUsedCode  vehicleModelYear  \
# 0                CAMRY                New              2022
# 1                 C-HR                New              2018
# ...

# %%
average_default_rate = df.groupby(['bins'])['intRate'].mean()
average_default_rate
#calculating average default rate for each bucket
# Out:
# bins
# (-0.001, 700.0]    0.067947
# (700.0, 737.0]     0.044254
# (737.0, 777.0]     0.037612
# (777.0, 819.0]     0.034522
# (819.0, 893.0]     0.032003
# Name: intRate, dtype: float64

# %% [markdown]
# ####

# %%
average_default_rate.plot.bar(rot = 1 , figsize = (8,8))
#bar graph of average default rate for each bucket
# Out:
# <AxesSubplot:xlabel='bins'>
